# %%
# !nvidia-smi

# %%
# !pip install ultralytics roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="sz9CSjjxPDTF0xpNuUn8")
project = rf.workspace("rehana-praveen-s-workspace").project("pothole_detection-tvecn")
version = project.version(7)
dataset = version.download("yolov8")

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')

results = model.train(
    data='/content/Pothole_Detection-7/data.yaml',
    epochs=100,
    batch=16,
    imgsz=640
)
