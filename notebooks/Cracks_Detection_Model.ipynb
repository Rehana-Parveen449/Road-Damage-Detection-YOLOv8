# %%
# !nvidia-smi

# %%
# !pip install ultralytics roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="sz9CSjjxPDTF0xpNuUn8")
project = rf.workspace("rehana-praveen-s-workspace").project("cracks_detection-i0gfp")
version = project.version(4)
dataset = version.download("yolov8")

# %%
from ultralytics import YOLO


model = YOLO('yolov8n-seg.pt')


results = model.train(
    data='/content/Cracks_Detection-4/data.yaml',
    epochs=100,
    imgsz=640,
    batch=16,
    name='cracks_model',
    save=True
)
