# %%
# !nvidia-smi

# %%
# !pip install ultralytics roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="sz9CSjjxPDTF0xpNuUn8")
project = rf.workspace("rehana-praveen-s-workspace").project("road_signs_detection-ofn9h")
version = project.version(1)
dataset = version.download("yolov8")

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')

results = model.train(
    data='/content/Road_Signs_Detection-1/data.yaml',
    epochs=100,
    batch=16,
    imgsz=640,
    patience=20,
    optimizer='Adam',
    lr0=0.001,
    name='roadsigns_seg'
)
